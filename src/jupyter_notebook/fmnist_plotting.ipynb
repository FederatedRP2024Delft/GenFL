        fmnist_local_baseline_2[idx],
        fmnist_local_baseline_3[idx],
        fmnist_local_baseline_4[idx],
        fmnist_local_baseline_5[idx]
    ])
)

fmnist_local_baseline_std = np.std(
    np.array([
        fmnist_local_baseline_1[idx],
        fmnist_local_baseline_2[idx],
        fmnist_local_baseline_3[idx],
        fmnist_local_baseline_4[idx],
        fmnist_local_baseline_5[idx]
    ])
)

fmnist_federated_baseline_avg = np.mean(
    np.array([
        fmnist_federated_baseline_1[idx],
        fmnist_federated_baseline_2[idx],
        fmnist_federated_baseline_3[idx],
        fmnist_federated_baseline_4[idx],
        fmnist_federated_baseline_5[idx]
    ])
)

fmnist_federated_baseline_std = np.std(
    np.array([
        fmnist_federated_baseline_1[idx],
        fmnist_federated_baseline_2[idx],
        fmnist_federated_baseline_3[idx],
        fmnist_federated_baseline_4[idx],
        fmnist_federated_baseline_5[idx]
    ])
)

fmnist_non_iid_100_0_avg = np.mean(
    np.array([
        fmnist_non_iid_100_0_1[idx],
        fmnist_non_iid_100_0_2[idx],
        fmnist_non_iid_100_0_3[idx],
        fmnist_non_iid_100_0_4[idx],
        fmnist_non_iid_100_0_5[idx]
    ])
)

fmnist_non_iid_100_0_std = np.std(
    np.array([
        fmnist_non_iid_100_0_1[idx],
        fmnist_non_iid_100_0_2[idx],
        fmnist_non_iid_100_0_3[idx],
        fmnist_non_iid_100_0_4[idx],
        fmnist_non_iid_100_0_5[idx]
    ])
)

fmnist_non_iid_10_0_avg = np.mean(
    np.array([
        fmnist_non_iid_10_0_1[idx],
        fmnist_non_iid_10_0_2[idx],
        fmnist_non_iid_10_0_3[idx],
        fmnist_non_iid_10_0_4[idx],
        fmnist_non_iid_10_0_5[idx]
    ])
)

fmnist_non_iid_10_0_std = np.std(
    np.array([
        fmnist_non_iid_10_0_1[idx],
        fmnist_non_iid_10_0_2[idx],
        fmnist_non_iid_10_0_3[idx],
        fmnist_non_iid_10_0_4[idx],
        fmnist_non_iid_10_0_5[idx]
    ])
)

fmnist_non_iid_1_0_avg = np.mean(
    np.array([
        fmnist_non_iid_1_0_1[idx],
        fmnist_non_iid_1_0_2[idx],
        fmnist_non_iid_1_0_3[idx],
        fmnist_non_iid_1_0_4[idx],
        fmnist_non_iid_1_0_5[idx]
    ])
)

fmnist_non_iid_1_0_std = np.std(
    np.array([
        fmnist_non_iid_1_0_1[idx],
        fmnist_non_iid_1_0_2[idx],
        fmnist_non_iid_1_0_3[idx],
        fmnist_non_iid_1_0_4[idx],
        fmnist_non_iid_1_0_5[idx]
    ])
)

fmnist_non_iid_0_1_avg = np.mean(
    np.array([
        fmnist_non_iid_0_1_1[idx],
        fmnist_non_iid_0_1_2[idx],
        fmnist_non_iid_0_1_3[idx],
        fmnist_non_iid_0_1_4[idx],
        fmnist_non_iid_0_1_5[idx]
    ])
)

fmnist_non_iid_0_1_std = np.std(
    np.array([
        fmnist_non_iid_0_1_1[idx],
        fmnist_non_iid_0_1_2[idx],
        fmnist_non_iid_0_1_3[idx],
        fmnist_non_iid_0_1_4[idx],
        fmnist_non_iid_0_1_5[idx]
    ])
)


fmnist_non_iid_0_01_avg = np.mean(
    np.array([
        fmnist_non_iid_0_01_1[idx],
        fmnist_non_iid_0_01_2[idx],
        fmnist_non_iid_0_01_3[idx],
        fmnist_non_iid_0_01_4[idx],
        fmnist_non_iid_0_01_5[idx]
    ])
)

fmnist_non_iid_0_01_std = np.std(
    np.array([
        fmnist_non_iid_0_01_1[idx],
        fmnist_non_iid_0_01_2[idx],
        fmnist_non_iid_0_01_3[idx],
        fmnist_non_iid_0_01_4[idx],
        fmnist_non_iid_0_01_5[idx]
    ])
)

print("Local baseline avg: ", np.around(fmnist_local_baseline_avg * 100, decimals=2))
print("Local baseline std: ", np.around(fmnist_local_baseline_std * 100, decimals=2))
print("Federated baseline avg: ", np.around(fmnist_federated_baseline_avg * 100, decimals=2))
print("Federated baseline std: ", np.around(fmnist_federated_baseline_std * 100, decimals=2))
print("Federated non-IID 100.0 avg: ", np.around(fmnist_non_iid_100_0_avg * 100, decimals=2))
print("Federated non-IID 100.0 std: ", np.around(fmnist_non_iid_100_0_std * 100, decimals=2))
print("Federated non-IID 10.0 avg: ", np.around(fmnist_non_iid_10_0_avg * 100, decimals=2))
print("Federated non-IID 10.0 std: ", np.around(fmnist_non_iid_10_0_std * 100, decimals=2))
print("Federated non-IID 1.0 avg: ", np.around(fmnist_non_iid_1_0_avg * 100, decimals=2))
print("Federated non-IID 1.0 std: ", np.around(fmnist_non_iid_1_0_std * 100, decimals=2))
print("Federated non-IID 0.1 avg: ", np.around(fmnist_non_iid_0_1_avg * 100, decimals=2))
print("Federated non-IID 0.1 std: ", np.around(fmnist_non_iid_0_1_std * 100, decimals=2))
print("Federated non-IID 0.01 avg: ", np.around(fmnist_non_iid_0_01_avg * 100, decimals=2))
print("Federated non-IID 0.01 std: ", np.around(fmnist_non_iid_0_01_std * 100, decimals=2))
# Out:
# Local baseline avg:  65.27
# Local baseline std:  0.52
# Federated baseline avg:  62.11
# Federated baseline std:  0.27
# Federated non-IID 100.0 avg:  63.41
# Federated non-IID 100.0 std:  0.13
# Federated non-IID 10.0 avg:  63.83
# Federated non-IID 10.0 std:  0.4
# Federated non-IID 1.0 avg:  63.9
# Federated non-IID 1.0 std:  0.28
# Federated non-IID 0.1 avg:  62.85
# Federated non-IID 0.1 std:  0.09
# Federated non-IID 0.01 avg:  48.71
# Federated non-IID 0.01 std:  0.47

# %%
plt.plot(x, fmnist_local_baseline_1, label='non-federated IID')
plt.plot(x, fmnist_federated_baseline_1, label='federated IID')
plt.plot(x, fmnist_non_iid_100_0_1, label='federated non-IID alpha=100.0', color='blue')
plt.plot(x, fmnist_non_iid_10_0_1, label='federated non-IID alpha=10.0', color='red')
plt.plot(x, fmnist_non_iid_1_0_1, label='federated non-IID alpha=1.0', color='green')
plt.plot(x, fmnist_non_iid_0_1_1, label='federated non-IID alpha=0.1', color='purple')
plt.plot(x, fmnist_non_iid_0_01_1, label='federated non-IID alpha=0.01', color='pink')
plt.gca().xaxis.set_major_locator(mticker.MultipleLocator
fmnist_non_iid_100_0_5 = [0.593086513789318, 0.5827475514782947, 0.6092030218623108, 0.6387273779215914, 0.6068728077478611, 0.6206366668557474, 0.6117833795105823, 0.6512099864551922, 0.6326535838114485, 0.6089283274090083, 0.6464990832866139, 0.6282979120190074, 0.6425444304289853, 0.6457355699620776, 0.6445934152423181, 0.6426536242989538, 0.6553149503102604, 0.634381334992734, 0.6498049780583351, 0.6360724686725747]

# %%
idx = 19

fmnist_local_baseline_avg = np.mean(
    np.array([
        fmnist_local_baseline_1[idx],
        fmnist_local_baseline_2[idx],
        fmnist_local_baseline_3[idx],
        fmnist_local_baseline_4[idx],
        fmnist_local_baseline_5[idx]
    ])
)

fmnist_local_baseline_std = np.std(
    np.array([
        fmnist_local_baseline_1[idx],
        fmnist_local_baseline_2[idx],
        fmnist_local_baseline_3[idx],
        fmnist_local_baseline_4[idx],
        fmnist_local_baseline_5[idx]
    ])
)

fmnist_federated_baseline_avg = np.mean(
    np.array([
        fmnist_federated_baseline_1[idx],
        fmnist_federated_baseline_2[idx],
        fmnist_federated_baseline_3[idx],
        fmnist_federated_baseline_4[idx],
        fmnist_federated_baseline_5[idx]
    ])
)

fmnist_federated_baseline_std = np.std(
    np.array([
        fmnist_federated_baseline_1[idx],
        fmnist_federated_baseline_2[idx],
        fmnist_federated_baseline_3[idx],
        fmnist_federated_baseline_4[idx],
        fmnist_federated_baseline_5[idx]
    ])
)

fmnist_non_iid_100_0_avg = np.mean(
    np.array([
        fmnist_non_iid_100_0_1[idx],
        fmnist_non_iid_100_0_2[idx],
        fmnist_non_iid_100_0_3[idx],
        fmnist_non_iid_100_0_4[idx],
        fmnist_non_iid_100_0_5[idx]
    ])
)

fmnist_non_iid_100_0_std = np.std(
    np.array([
        fmnist_non_iid_100_0_1[idx],
        fmnist_non_iid_100_0_2[idx],
        fmnist_non_iid_100_0_3[idx],
        fmnist_non_iid_100_0_4[idx],
        fmnist_non_iid_100_0_5[idx]
    ])
)

fmnist_non_iid_10_0_avg = np.mean(
    np.array([
        fmnist_non_iid_10_0_1[idx],
        fmnist_non_iid_10_0_2[idx],
        fmnist_non_iid_10_0_3[idx],
        fmnist_non_iid_10_0_4[idx],
        fmnist_non_iid_10_0_5[idx]
    ])
)

fmnist_non_iid_10_0_std = np.std(
    np.array([
        fmnist_non_iid_10_0_1[idx],
        fmnist_non_iid_10_0_2[idx],
        fmnist_non_iid_10_0_3[idx],
        fmnist_non_iid_10_0_4[idx],
        fmnist_non_iid_10_0_5[idx]
    ])
)

fmnist_non_iid_1_0_avg = np.mean(
    np.array([
        fmnist_non_iid_1_0_1[idx],
        fmnist_non_iid_1_0_2[idx],
        fmnist_non_iid_1_0_3[idx],
        fmnist_non_iid_1_0_4[idx],
        fmnist_non_iid_1_0_5[idx]
    ])
)

fmnist_non_iid_1_0_std = np.std(
    np.array([
        fmnist_non_iid_1_0_1[idx],
        fmnist_non_iid_1_0_2[idx],
        fmnist_non_iid_1_0_3[idx],
        fmnist_non_iid_1_0_4[idx],
        fmnist_non_iid_1_0_5[idx]
    ])
)

fmnist_non_iid_0_1_avg = np.mean(
    np.array([
        fmnist_non_iid_0_1_1[idx],
        fmnist_non_iid_0_1_2[idx],
        fmnist_non_iid_0_1_3[idx],
        fmnist_non_iid_0_1_4[idx],
        fmnist_non_iid_0_1_5[idx]
    ])
)

fmnist_non_iid_0_1_std = np.std(
    np.array([
        fmnist_non_iid_0_1_1[idx],
        fmnist_non_iid_0_1_2[idx],
        fmnist_non_iid_0_1_3[idx],
        fmnist_non_iid_0_1_4[idx],
        fmnist_non_iid_0_1_5[idx]
    ])
)


fmnist_non_iid_0_01_avg = np.mean(
    np.array([
        fmnist_non_iid_0_01_1[idx],
        fmnist_non_iid_0_01_2[idx],
        fmnist_non_iid_0_01_3[idx],
        fmnist_non_iid_0_01_4[idx],
        fmnist_non_iid_0_01_5[idx]
    ])
)

fmnist_non_iid_0_01_std = np.std(
    np.array([
        fmnist_non_iid_0_01_1[idx],
        fmnist_non_iid_0_01_2[idx],
        fmnist_non_iid_0_01_3[idx],
        fmnist_non_iid_0_01_4[idx],
        fmnist_non_iid_0_01_5[idx]
    ])
)

print("Local baseline avg: ", np.around(fmnist_local_baseline_avg * 100, decimals=2))
print("Local baseline std: ", np.around(fmnist_local_baseline_std * 100, decimals=2))
print("Federated baseline avg: ", np.around(fmnist_federated_baseline_avg * 100, decimals=2))
print("Federated baseline std: ", np.around(fmnist_federated_baseline_std * 100, decimals=2))
print("Federated non-IID 100.0 avg: ", np.around(fmnist_non_iid_100_0_avg * 100, decimals=2))
print("Federated non-IID 100.0 std: ", np.around(fmnist_non_iid_100_0_std * 100, decimals=2))
print("Federated non-IID 10.0 avg: ", np.around(fmnist_non_iid_10_0_avg * 100, decimals=2))
print("Federated non-IID 10.0 std: ", np.around(fmnist_non_iid_10_0_std * 100, decimals=2))
print("Federated non-IID 1.0 avg: ", np.around(fmnist_non_iid_1_0_avg * 100, decimals=2))
print("Federated non-IID 1.0 std: ", np.around(fmnist_non_iid_1_0_std * 100, decimals=2))
print("Federated non-IID 0.1 avg: ", np.around(fmnist_non_iid_0_1_avg * 100, decimals=2))
print("Federated non-IID 0.1 std: ", np.around(fmnist_non_iid_0_1_std * 100, decimals=2))
print("Federated non-IID 0.01 avg: ", np.around(fmnist_non_iid_0_01_avg * 100, decimals=2))
print("Federated non-IID 0.01 std: ", np.around(fmnist_non_iid_0_01_std * 100, decimals=2))
# Out:
# Local baseline avg:  65.91
# Local baseline std:  1.21
# Federated baseline avg:  62.79
# Federated baseline std:  1.22
# Federated non-IID 100.0 avg:  63.27
# Federated non-IID 100.0 std:  0.72
# Federated non-IID 10.0 avg:  63.76
# Federated non-IID 10.0 std:  0.41
# Federated non-IID 1.0 avg:  64.5
# Federated non-IID 1.0 std:  0.63
# Federated non-IID 0.1 avg:  63.29
# Federated non-IID 0.1 std:  0.53
# Federated non-IID 0.01 avg:  47.73
# Federated non-IID 0.01 std:  0.95
